# %% [markdown]
# # Phase 4: Curation & Quality Control
# Generate a curation template, review stems, and create a curated selection.

# %%
from pipeline.config import load_config
from pipeline.curate import generate_curation_template, show_curation_stats

# %%
config = load_config()

# %% [markdown]
# ## Generate Curation Template

# %%
generate_curation_template(
    metadata_csv=config["ANALYZED_DIR"] / "metadata.csv",
    output_csv=config["CURATED_DIR"] / "curation_template.csv",
)

# %% [markdown]
# ## Review Selection
# After editing the template CSV (mark `include` as `yes`/`no`), load and review:

# %%
# Set the path to your edited selection CSV
selection_csv = config["CURATED_DIR"] / "curation_template.csv"
show_curation_stats(selection_csv)
