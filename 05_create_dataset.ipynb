# %% [markdown]
# # Phase 5: Create MusicGen Dataset
# Generate 30-second audio clips with text captions for MusicGen fine-tuning.

# %%
from pipeline.config import load_config
from pipeline.dataset import create_dataset

# %%
config = load_config()

# %% [markdown]
# ## Create Dataset from Curated Selection

# %%
create_dataset(
    selection_csv=config["CURATED_DIR"] / "curation_template.csv",
    stems_dir=config["STEMS_DIR"],
    output_dir=config["DATASET_DIR"],
)

# %% [markdown]
# ## Next Steps
# See `references/finetuning.md` for MusicGen fine-tuning instructions.
