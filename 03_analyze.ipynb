# %% [markdown]
# # Phase 3: Audio Analysis
# Detect tempo (BPM), musical key, duration, and loudness metrics for each stem.
# Parallel processing across 6 CPU cores.

# %%
from pipeline.config import load_config
from pipeline.analyze import run_analysis
import pandas as pd

# %%
config = load_config()

# %% [markdown]
# ## Run Analysis

# %%
metadata_csv = config["ANALYZED_DIR"] / "metadata.csv"
df = run_analysis(config["STEMS_DIR"], metadata_csv, num_workers=config["NUM_WORKERS"])

# %% [markdown]
# ## Review Results

# %%
display(df.head(20))
df.describe()
